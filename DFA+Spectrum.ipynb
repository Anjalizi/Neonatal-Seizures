# %%
import numpy as np
import matplotlib.pyplot as plt

import mne

# %%
data = mne.io.read_raw_edf('eeg10.edf', preload=True)
# Out:
# Extracting EDF parameters from /home/anjali/Desktop/Mehnat/BTP2/eeg10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1389311  =      0.000 ...  5426.996 secs...

# %%
import pyeeg as p
df = data.to_data_frame()
p.dfa(df)
# Out:
# Converting "time" to "<class 'numpy.int64'>"...
# 1.321688988381152

# %%
from scipy.io import loadmat
import scipy
import numpy as np
from pylab import *
import matplotlib.pyplot as plt

sfreq = data.info['sfreq']
data, times = data[:, int(sfreq * 1):int(sfreq * 10)]
fig = plt.subplots(figsize=(10,8))
plt.plot(times, data5.T);

fft1 = scipy.fft(data)
fs = sfreq
f = np.linspace(0,fs,len(data), endpoint=False)
plt.figure(1)
plt.plot(f, abs(fft1))
plt.legend(f)
plt.title('Magnitude spectrum of the signal')
plt.xlabel('Frequency (Hz)')
show()
