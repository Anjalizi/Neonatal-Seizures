# %%
import pandas as pd

# %%
test = pd.read_csv('Neonatal_Test_Data.csv')
test
# Out:
#     Signal   Mean (µV)    RMS (µV)    MRS (µV)  Zero Crossings  \
# 0    e33.1  -50.052100  100.317500   72.246000              19
# 1    e33.2    7.292800   75.902800   49.498800              17
# 2    e33.3   -2.425700   92.776400   61.022100              24
# 3    e33.4   32.772100  109.562600   81.080800              16
# 4    e33.5  -96.931700  268.678400  220.897700               9
# ..     ...         ...         ...         ...             ...
# 95  e42.16   23.057257  207.626979  139.657707              18
# 96  e42.17  217.713307  275.548367  228.020558               8
# 97  e42.18  304.664120  458.527973  353.720747              10
# 98  e42.19  197.122273  254.840490  201.990622               6
# 99  e42.20  193.166933  282.300492  214.287301               8
#
#     Frequency (Hz)  Delta (µV² /Hz)  Theta (µV² /Hz)  Alpha (µV² /Hz)  \
# 0              9.5         0.613506         0.110539         0.141143
# ...
